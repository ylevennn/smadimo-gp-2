# %% [markdown]
# Ниже выполним подготовку финального, спаршенного датасета. А именно - объединим все полученные части в один большой датасет

# %% [markdown]
# Объявим логгер и подключим библиотеки

# %%
import pandas as pd
import os
import sys

sys.path.append(os.path.abspath(".."))
from logs.logger import logger

log = logger()

# %% [markdown]
# Получим имена всех собранных датасетов

# %%
# https://sky.pro/wiki/media/rabota-s-fajlami-v-python-kak-poluchit-spisok-vseh-fajlov-v-direktorii/
files_in_data = os.listdir('../../data')

# %%
games_data_datasets = []
for f in files_in_data:
    if f.startswith('games_data_'):
        games_data_datasets.append(f)

games_data_datasets
# Out:
# ['games_data_[11000-11500].xlsx',
#  'games_data_[7000-7500].xlsx',
#  'games_data_[26500-27000].xlsx',
#  'games_data_[26000-26500].xlsx',
#  'games_data_[1500-2000].xlsx',
#  'games_data_[15500-16000].xlsx',
#  'games_data_[19500-20500].xlsx',
#  'games_data_[10500-11000].xlsx',
#  'games_data_[2500-3000].xlsx',
#  'games_data_[27000-27500].xlsx',
#  'games_data_[21500-22500].xlsx',
#  'games_data_[10000-10500].xlsx',
#  'games_data_[2000-2500].xlsx',
#  'games_data_[25500-26000].xlsx',
#  'games_data_[17000-17500].xlsx',
#  'games_data_[8500-9000].xlsx',
#  'games_data_[500-1000].xlsx',
#  'games_data_[8000-8500].xlsx',
#  'games_data_[5000-5500].xlsx',
#  'games_data_[9500-10000].xlsx',
#  'games_data_[16500-17000].xlsx',
#  'games_data_[16000-16500].xlsx',
#  'games_data_[22500-23500].xlsx',
#  'games_data_[0-500].xlsx',
#  'games_data_[4000-4500].xlsx',
#  'games_data_[15000-15500].xlsx',
#  'games_data_[18000-19500].xlsx',
#  'games_data_[17500-18000].xlsx',
#  'games_data_[4500-5000].xlsx',
#  'games_data_[14500-15000].xlsx',
#  'games_data_[3500-4000].xlsx',
#  'games_data_[11500-12000].xlsx',
#  'games_data_[14000-14500].xlsx',
#  'games_data_[1000-1500].xlsx',
#  'games_data_[9000-9500].xlsx',
#  'games_data_[13500-14000].xlsx',
#  'games_data_[20500-21500].xlsx',
#  'games_data_[13000-13500].xlsx',
#  'games_data_[24500-25000].xlsx',
#  'games_data_[5500-6000].xlsx',
#  'games_data_[3000-3500].xlsx',
#  'games_data_[7500-8000].xlsx',
#  'games_data_[24000-24500].xlsx',
#  'games_data_[23500-24000].xlsx',
#  'games_data_[6000-6500].xlsx',
#  'games_data_[12500-13000].xlsx',
#  'games_data_[25000-25500].xlsx',
#  'games_data_[6500-7000].xlsx',
#  'games_data_[12000-12500].xlsx']

# %% [markdown]
# Откроем каждый файл и объединим в общий датасет

# %%
df_parsed = None
for filename in games_data_datasets:
    if df_parsed is None:
        df_parsed = pd.read_excel('../../data/' + filename)
        log.info(f'Добавален первый датасет {filename} | всего строк = {df_parsed.shape[0]}')
        continue

    df_temp = pd.read_excel('../../data/' + filename)
    df_parsed = pd.concat([df_parsed, df_temp], axis=0)
    log.info(f'Добавален датасет {filename} | всего строк в текущем df_parsed = {df_parsed.shape[0]}')

log.info(f'Общий df_parsed собран | всего строк {df_parsed.shape[0]}')
# Out:
# 2026-04-07 23:54:28,585 - 1205378049.py - INFO - Добавален первый датасет games_data_[11000-11500].xlsx | всего строк = 495
# 2026-04-07 23:54:28,627 - 1205378049.py - INFO - Добавален датасет games_data_[7000-7500].xlsx | всего строк в текущем df_parsed = 989
# 2026-04-07 23:54:28,655 - 1205378049.py - INFO - Добавален датасет games_data_[26500-27000].xlsx | всего строк в текущем df_parsed = 1488
# 2026-04-07 23:54:28,683 - 1205378049.py - INFO - Добавален датасет games_data_[26000-26500].xlsx | всего строк в текущем df_parsed = 1978
# 2026-04-07 23:54:28,713 - 1205378049.py - INFO - Добавален датасет games_data_[1500-2000].xlsx | всего строк в текущем df_parsed = 2472
# 2026-04-07 23:54:28,740 - 1205378049.py - INFO - Добавален датасет games_data_[15500-16000].xlsx | всего строк в текущем df_parsed = 2969
# 2026-04-07 23:54:28,791 - 1205378049.py - INFO - Добавален датасет games_data_[19500-20500].xlsx | всего строк в текущем df_parsed = 3962
# 2026-04-07 23:54:28,819 - 1205378049.py - INFO - Добавален датасет games_data_[10500-11000].xlsx | всего строк в текущем df_parsed = 4455
# 2026-04-07 23:54:28,847 - 1205378049.py - INFO - Добавален датасет games_data_[2500-3000].xlsx | всего строк в текущем df_parsed = 4953
# 2026-04-07 23:54:28,875 - 1205378049.py - INFO - Добавален датасет games_data_[27000-27500].xlsx | всего строк в текущем df_parsed = 5451
# 2026-04-07 23:54:28,893 - 1205378049.py - INFO - Добавален датасет games_data_[21500-22500].xlsx | всего строк в текущем df_parsed = 6444
# 2026-04-07 23:54:28,937 - 1205378049.py - INFO - Добавален датасет games_data_[10000-10500].xlsx | всего строк в текущем df_parsed = 6943
# 2026-04-07 23:54:28,968 - 1205378049.py - INFO - Добавален датасет games_data_[2000-2500].xlsx | всего строк в текущем df_parsed = 7442
# 2026-04-07 23:54:28,997 - 1205378049.py - INFO - Добавален датасет games_data_[25500-26000].xlsx | всего строк в текущем df_parsed = 7941
# 2026-04-07 23:54:29,026 - 1205378049.py - INFO - Добавален датасет games_data_[17000-17500].xlsx | всего строк в текущем df_parsed = 8439
# 2026-04-07 23:54:29,042 - 1205378049.py - INFO - Добавален датасет games_data_[8500-9000].xlsx | всего строк в текущем df_parsed = 8683
# 2026-04-07 23:54:29,072 - 1205378049.py - INFO - Добавален датасет games_data_[500-1000].xlsx | всего строк в текущем df_parsed = 9179
# 2026-04-07 23:54:29,102 - 1205378049.py - INFO - Добавален датасет games_data_[8000-8500].xlsx | всего строк в текущем df_parsed = 9676
# 2026-04-07 23:54:29,135 - 1205378049.py - INFO - Добавален датасет games_data_[5000-5500].xlsx | всего строк в текущем df_parsed = 10173
# 2026-04-07 23:54:29,163 - 1205378049.py - INFO - Добавален датасет games_data_[9500-10000].xlsx | всего строк в текущем df_parsed = 10666
# 2026-04-07 23:54:29,197 - 1205378049.py - INFO - Добавален датасет games_data_[16500-17000].xlsx | всего строк в текущем df_parsed = 11162
# 2026-04-07 23:54:29,242 - 1205378049.py - INFO - Добавален датасет games_data_[16000-16500].xlsx | всего строк в текущем df_parsed = 11654
# 2026-04-07 23:54:29,299 - 1205378049.py - INFO - Добавален датасет games_data_[22500-23500].xlsx | всего строк в текущем df_parsed = 12646
# 2026-04-07 23:54:29,329 - 1205378049.py - INFO - Добавален датасет games_data_[0-500].xlsx | всего строк в текущем df_parsed = 13145
# 2026-04-07 23:54:29,358 - 1205378049.py - INFO - Добавален датасет games_data_[4000-4500].xlsx | всего строк в текущем df_parsed = 13645
# 2026-04-07 23:54:29,388 - 1205378049.py - INFO - Добавален датасет games_data_[15000-15500].xlsx | всего строк в текущем df_parsed = 14144
# 2026-04-07 23:54:29,467 - 1205378049.py - INFO - Добавален датасет games_data_[18000-19500].xlsx | всего строк в текущем df_parsed = 15634
# 2026-04-07 23:54:29,499 - 1205378049.py - INFO - Добавален датасет games_data_[17500-18000].xlsx | всего строк в текущем df_parsed = 16126
# 2026-04-07 23:54:29,544 - 1205378049.py - INFO - Добавален датасет games_data_[4500-5000].xlsx | всего строк в текущем df_parsed = 16623
# 2026-04-07 23:54:29,576 - 1205378049.py - INFO - Добавален датасет games_data_[14500-15000].xlsx | всего строк в текущем df_parsed = 17121
# 2026-04-07 23:54:29,606 - 1205378049.py - INFO - Добавален датасет games_data_[3500-4000].xlsx | всего строк в текущем df_parsed = 17619
# 2026-04-07 23:54:29,636 - 1205378049.py - INFO - Добавален датасет games_data_[11500-12000].xlsx | всего строк в текущем df_parsed = 18112
# 2026-04-07 23:54:29,656 - 1205378049.py - INFO - Добавален датасет games_data_[14000-14500].xlsx | всего строк в текущем df_parsed = 18425
# 2026-04-07 23:54:29,688 - 1205378049.py - INFO - Добавален датасет games_data_[1000-1500].xlsx | всего строк в текущем df_parsed = 18922
# 2026-04-07 23:54:29,718 - 1205378049.py - INFO - Добавален датасет games_data_[9000-9500].xlsx | всего строк в текущем df_parsed = 19420
# 2026-04-07 23:54:29,747 - 1205378049.py - INFO - Добавален датасет games_data_[13500-14000].xlsx | всего строк в текущем df_parsed = 19911
# 2026-04-07 23:54:29,802 - 1205378049.py - INFO - Добавален датасет games_data_[20500-21500].xlsx | всего строк в текущем df_parsed = 20894
# 2026-04-07 23:54:29,848 - 1205378049.py - INFO - Добавален датасет games_data_[13000-13500].xlsx | всего строк в текущем df_parsed = 21392
# 2026-04-07 23:54:29,880 - 1205378049.py - INFO - Добавален датасет games_data_[24500-25000].xlsx | всего строк в текущем df_parsed = 21892
# 2026-04-07 23:54:29,912 - 1205378049.py - INFO - Добавален датасет games_data_[5500-6000].xlsx | всего строк в текущем df_parsed = 22388
# 2026-04-07 23:54:29,942 - 1205378049.py - INFO - Добавален датасет games_data_[3000-3500].xlsx | всего строк в текущем df_parsed = 22886
# 2026-04-07 23:54:29,972 - 1205378049.py - INFO - Добавален датасет games_data_[7500-8000].xlsx | всего строк в текущем df_parsed = 23381
# 2026-04-07 23:54:30,001 - 1205378049.py - INFO - Добавален датасет games_data_[24000-24500].xlsx | всего строк в текущем df_parsed = 23871
# 2026-04-07 23:54:30,032 - 1205378049.py - INFO - Добавален датасет games_data_[23500-24000].xlsx | всего строк в текущем df_parsed = 24366
# 2026-04-07 23:54:30,061 - 1205378049.py - INFO - Добавален датасет games_data_[6000-6500].xlsx | всего строк в текущем df_parsed = 24865
# 2026-04-07 23:54:30,090 - 1205378049.py - INFO - Добавален датасет games_data_[12500-13000].xlsx | всего строк в текущем df_parsed = 25361
# 2026-04-07 23:54:30,120 - 1205378049.py - INFO - Добавален датасет games_data_[25000-25500].xlsx | всего строк в текущем df_parsed = 25859
# 2026-04-07 23:54:30,163 - 1205378049.py - INFO - Добавален датасет games_data_[6500-7000].xlsx | всего строк в текущем df_parsed = 26355
# 2026-04-07 23:54:30,192 - 1205378049.py - INFO - Добавален датасет games_data_[12000-12500].xlsx | всего строк в текущем df_parsed = 26853
# 2026-04-07 23:54:30,192 - 1205378049.py - INFO - Общий df_parsed собран | всего строк 26853

# %%
df_parsed
# Out:
#      steam_id                          game_name  \
# 0      789570                           Nepenthe
# 1     1424520                             Astria
# 2      751590  Dinosaurs A Prehistoric Adventure
# 3      446550                                NaN
# 4      467850                            METAGAL
# ..        ...                                ...
# 493    302570                          Dangerous
# 494    911130           Puzzle Monarch: Vampires
# 495    347820                       Street Arena
# 496   1212040  Paws & Effect: My Dogs Are Human!
# 497    854150                Snail Racer Extreme
#
#                               game_description_snippet game_price  \
# 0    Там, куда вы идёте, вам не понадобится стрижка...   133 руб.
# 1    Enter the doomed world of Astria, a land destr...  Бесплатно
# 2    Be the dinosaur! Experience the world of dinos...  Бесплатно
# 3                                                  NaN        NaN
# 4    Help the young cyborg-girl Meta , in her battl...   200 руб.
# ..                                                 ...        ...
# 493  Dangerous is an epic 3D open and living world ...   419 руб.
# 494  An ancient tomb has been uncovered and it's fi...   200 руб.
# 495  Надери задницу друзьям в этой взрывной, динами...   169 руб.
# 496  A quirky, comedic visual novel where dogs tran...        NaN
# 497  Come play this extremely addictive and fun sna...        NaN
#
#      found_game_price all_language_reviews_type  all_language_reviews_count  \
# 0                 1.0       Очень положительные                        76.0
# 1                 1.0       Очень положительные                       104.0
# 2                 1.0                 Смешанные                       216.0
# 3                 NaN                       NaN                         NaN
# 4                 1.0                 Смешанные                       138.0
# ..                ...                       ...                         ...
# 493               1.0  В основном отрицательные                        34.0
# 494               1.0                 Смешанные                        23.0
# 495               1.0                 Смешанные                        45.0
# 496               0.0  Обзоров пользователей: 9                         9.0
# 497               0.0  Обзоров пользователей: 5                         5.0
#
#      has_russian_reviews all_russian_reviews_type  all_russian_reviews_count  \
# 0                    0.0                      NaN                        NaN
# 1                    0.0                      NaN                        NaN
# 2                    0.0                      NaN                        NaN
# 3                    NaN                      NaN                        NaN
# 4                    0.0                      NaN                        NaN
# ..                   ...                      ...                        ...
# 493                  0.0                      NaN                        NaN
# 494                  0.0                      NaN                        NaN
# 495                  0.0                      NaN                        NaN
# 496                  0.0                      NaN                        NaN
# 497                  0.0                      NaN                        NaN
#
#                                    steam_app_url support_ru_region
# 0     https://store.steampowered.com/app/789570/               1.0
# 1    https://store.steampowered.com/app/1424520/               1.0
# 2     https://store.steampowered.com/app/751590/               1.0
# 3     https://store.steampowered.com/app/446550/               0.0
# 4     https://store.steampowered.com/app/467850/               1.0
# ..                                           ...               ...
# 493   https://store.steampowered.com/app/302570/              True
# 494   https://store.steampowered.com/app/911130/              True
# 495   https://store.steampowered.com/app/347820/              True
# 496  https://store.steampowered.com/app/1212040/              True
# 497   https://store.steampowered.com/app/854150/              True
#
# [26853 rows x 12 columns]

# %%
df_parsed.to_excel('../../data/df_parsed.xlsx', index=False)
